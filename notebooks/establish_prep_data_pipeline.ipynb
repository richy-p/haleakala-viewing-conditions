# %% [markdown]
# # Establish Prep Data Pipeline

# %%
# set up path to import my python scripts
import sys
import os
src_path = os.path.abspath(os.path.join('..'))
if src_path not in sys.path:
    sys.path.append(src_path+"/src")

# %%
# %load_ext autoreload
# %autoreload 2
import prep_data as prep

# %%
import pandas as pd
import numpy as np

# %%
# link for data files
base_url = "http://kopiko.ifa.hawaii.edu/weather/archivedata/"

# data column names
column_names = ['date_time','temperature','pressure','humidity','wind_speed','wind_direction','visibility','co2','insolation','vertical_wind_speed','precipitation','10min','dewpoint']
columns_of_interest = ['date_time','temperature','humidity','wind_speed','visibility','precipitation','dewpoint','10min']

# Define reasonable ranges for each column
acceptable_ranges = {
    'temperature': (-273,40),
    'humidity': (0,100),
    'wind_speed': (0,100),
    'visibility': (0,100000),
    'precipitation': (0,100),
    'dewpoint': (-273,40)
    }
# Define the thresholds for ('Green', 'Red') weather - plan to use config file in future
thresholds = {
        'humidity': (75,85),
        'wind_sust': (10,12),
        'wind_gust': (15,15),
        'visibility': (50000,40000),
        'precipitation': (0,0),
        'dewpoint_delta': (6,3)
        }

# %% [markdown]
# ## Set up for loop with try except in case the file doesn't load

# %%
# get list of all data file urls
csv_urls = prep.get_csv_file_links(base_url)

# %%
# get list of all data file urls
temp_csv_urls = ['1564.csv',csv_urls[0],csv_urls[1],'2023.csv']

for url in temp_csv_urls:
    # grab the year 
    year = url.split('/')[-1].split('.')[0]
    try:
        df = prep.read_data_of_interest(url,column_names,columns_of_interest)
    except:
        print(f'Failed to read data for {year} at: {url} ')
        continue
    print(f'{year} data loaded, run rest of code')
# Out:
# Failed to read data for 1564 at: 1564.csv
# 1993 data loaded, run rest of code
# 1994 data loaded, run rest of code
# Failed to read data for 2023 at: 2023.csv

# %%
df
# Out:
#                      temperature  humidity  wind_speed  visibility  \
# date_time
# 1994-09-11 17:20:00        13.93       NaN       7.350         NaN
# 1994-09-11 17:30:00        13.48       NaN       7.290         NaN
# 1994-09-11 17:40:00        13.67       NaN       7.140         NaN
# 1994-09-11 17:50:00        13.95       NaN       7.310         NaN
# 1994-09-11 18:00:00        13.85       NaN       7.960         NaN
# ...                          ...       ...         ...         ...
# 1994-12-31 23:10:00        17.21       NaN       2.825         NaN
# 1994-12-31 23:20:00        17.18       NaN       2.209         NaN
# 1994-12-31 23:30:00        17.55       NaN       3.314         NaN
# 1994-12-31 23:40:00        17.09       NaN       3.867         NaN
# 1994-12-31 23:50:00        16.96       NaN       3.771         NaN
#
#                      precipitation  dewpoint  10min
# date_time
# 1994-09-11 17:20:00            0.0       NaN      1
# 1994-09-11 17:30:00            0.0       NaN      1
# 1994-09-11 17:40:00            0.0       NaN      1
# 1994-09-11 17:50:00            0.0       NaN      1
# 1994-09-11 18:00:00            0.0       NaN      1
# ...                            ...       ...    ...
# 1994-12-31 23:10:00            0.0       NaN      1
# 1994-12-31 23:20:00            0.0       NaN      1
# 1994-12-31 23:30:00            0.0       NaN      1
# 1994-12-31 23:40:00            0.0       NaN      1
# 1994-12-31 23:50:00            0.0       NaN      1
#
# [14025 rows x 7 columns]

# %%
year = 2020
link = prep.get_specific_year(2020,csv_urls)
df = prep.read_data_of_interest(url,column_names,columns_of_interest)
# Out:
# /tmp/ipykernel_5413/2812443234.py:3: DtypeWarning: Columns (9,12) have mixed types.Specify dtype option on import or set low_memory=False.
#   df = prep.read_data_of_interest(url,column_names,columns_of_interest)

# %%
df
# Out:
#                      temperature  humidity  wind_speed  visibility  \
# date_time
# 2020-01-01 00:00:00        11.33      10.1        16.7     50000.0
# 2020-01-01 00:00:10        11.31      10.4        17.1     50000.0
# 2020-01-01 00:00:20        11.31      10.3        16.5     50000.0
# 2020-01-01 00:00:30        11.31       9.6        17.1     50000.0
# 2020-01-01 00:00:41        11.32       9.2        18.2     50000.0
# ...                          ...       ...         ...         ...
# 2020-12-31 23:59:16         6.46      25.8        11.1     50000.0
# 2020-12-31 23:59:26         6.47      25.2        12.1     50000.0
# 2020-12-31 23:59:36         6.46      24.9        15.1     50000.0
# 2020-12-31 23:59:46         6.47      26.8        14.1     50000.0
# 2020-12-31 23:59:56         6.47      29.1        16.0     50000.0
#
#                      precipitation dewpoint  10min
# date_time
# 2020-01-01 00:00:00            NaN      NaN    0.0
# 2020-01-01 00:00:10            NaN      NaN    0.0
# 2020-01-01 00:00:20            NaN      NaN    0.0
# 2020-01-01 00:00:30            NaN      NaN    0.0
# 2020-01-01 00:00:41            NaN      NaN    0.0
# ...                            ...      ...    ...
# 2020-12-31 23:59:16            NaN   -10.26    NaN
# 2020-12-31 23:59:26            NaN      NaN    NaN
# 2020-12-31 23:59:36            NaN      NaN    NaN
# 2020-12-31 23:59:46            NaN      NaN    NaN
# 2020-12-31 23:59:56            NaN      NaN    NaN
#
# [2605375 rows x 7 columns]

# %% [markdown]
# ## Rest of pipeline (actually in the for loop)

# %%
# check for reasonable values
prep.remove_unreasonable_measurements(df,acceptable_ranges,inplace=True)

# split wind into sustaind and gusts
df = prep.determine_wind_sust_and_gust(df)

# add delta dew point
df['dewpoint_delta'] = df['temperature'] - df['dewpoint']

# convert thresholds to status
df['status'] = prep.get_weather_status(df,thresholds)

# make new df with daily hours
df_status_hours = prep.generate_status_hours_df(df)

# save new df
prep.save_df_to_csv(df_status_hours,year)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_5413/3836077382.py in <module>
#       1 # check for reasonable values
# ----> 2 prep.remove_unreasonable_measurements(df,acceptable_ranges,inplace=True)
#       3
#       4 # split wind into sustaind and gusts
#       5 df = prep.determine_wind_sust_and_gust(df)
#
# ~/Documents/dai/repos/haleakala-viewing-conditions/src/prep_data.py in remove_unreasonable_measurements(df, range_limits, inplace)
#     129     df_new = pd.DataFrame()
#     130     for col in df.drop(['10min'],axis=1).columns:
# --> 131         df_new[col] = df[col].mask((df[col]<range_limits[col][0]) | (df[col]>range_limits[col][1]),inplace=inplace)
#     132     if not inplace:
#     133         return df_new
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/common.py in new_method(self, other)
#      67         other = item_from_zerodim(other)
#      68
# ---> 69         return method(self, other)
#      70
#      71     return new_method
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/arraylike.py in __lt__(self, other)
#      38     @unpack_zerodim_and_defer("__lt__")
#      39     def __lt__(self, other):
# ---> 40         return self._cmp_method(other, operator.lt)
#      41
#      42     @unpack_zerodim_and_defer("__le__")
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/series.py in _cmp_method(self, other, op)
#    5500
#    5501         with np.errstate(all="ignore"):
# -> 5502             res_values = ops.comparison_op(lvalues, rvalues, op)
#    5503
#    5504         return self._construct_result(res_values, name=res_name)
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comparison_op(left, right, op)
#     282
#     283     elif is_object_dtype(lvalues.dtype) or isinstance(rvalues, str):
# --> 284         res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     285
#     286     else:
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/core/ops/array_ops.py in comp_method_OBJECT_ARRAY(op, x, y)
#      71         result = libops.vec_compare(x.ravel(), y.ravel(), op)
#      72     else:
# ---> 73         result = libops.scalar_compare(x.ravel(), y, op)
#      74     return result.reshape(x.shape)
#      75
#
# ~/anaconda3/lib/python3.9/site-packages/pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '<' not supported between instances of 'str' and 'int'
